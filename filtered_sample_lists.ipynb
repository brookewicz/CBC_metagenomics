# %% [markdown]
# # Filtered Sample Lists
# - creating different sample lists that fit different conditions to use in assembly set
# - purpose of this is to try assembling with similar sample types to get better results

# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/metadata')

# %%
ls
# Out:
# CBC_ColonyData.csv              Metagenomics_Tracker_Belize.csv
# CBC_ColonyData_replacement.csv  disease_over_time.jpeg
# CBC_samples.csv                 healthy_2019_MCAV

# %%
sample_data=pd.read_csv('Metagenomics_Tracker_Belize.csv', index_col=0)

# %%
sample_data.head()
# Out:
#                             Health_Status  Starting_Weight   Extracted  \
# 052022_BEL_CBC_T2_45_PSTR  Diseased_Margin             181  10_10_2023
# 052022_BEL_CBC_T2_46_PSTR  Diseased_Tissue             162  10_10_2023
# 052022_BEL_CBC_T2_59_OFAV          Healthy             174   10_3_2023
# 052022_BEL_CBC_T2_69_OANN          Healthy             134   10_3_2023
# 052022_BEL_CBC_T2_72_OFAV          Healthy              75   10_3_2023
#
#                           Raw_ng_ul Date_Enriched Microbe_ng_ul  \
# 052022_BEL_CBC_T2_45_PSTR      22.8    10_17_2023           7.5
# 052022_BEL_CBC_T2_46_PSTR      63.9    10_17_2023          18.5
# 052022_BEL_CBC_T2_59_OFAV      73.7    10_16_2023          11.7
# 052022_BEL_CBC_T2_69_OANN     133.1           NaN           NaN
# 052022_BEL_CBC_T2_72_OFAV      47.6      10_11_23          3.96
#
#                           Microbe_Location Microbe_clean_date/n Host_ng_ul  \
# ...

# %%
# make a column for year 

# Extract year from the sample names
def extract_year(sample_name):
    return sample_name.split('_')[0][2:]

# Create a new column 'Year' using the 'apply' function
sample_data['Year'] = sample_data.index.to_series().apply(extract_year)

# Print the updated DataFrame
print(sample_data['Year'])
# Out:
# 052022_BEL_CBC_T2_45_PSTR    2022
# 052022_BEL_CBC_T2_46_PSTR    2022
# 052022_BEL_CBC_T2_59_OFAV    2022
# 052022_BEL_CBC_T2_69_OANN    2022
# 052022_BEL_CBC_T2_72_OFAV    2022
#                              ...
# 062019_BEL_CBC_T1_3_MCAV     2019
# 062019_BEL_CBC_T2_5_MCAV     2019
# 062019_BEL_CBC_T3_4_PAST     2019
# 062019_BEL_CBC_T3_6_MCAV     2019
# 102019_BEL_CBC_T2_35_PSTR    2019
# Name: Year, Length: 103, dtype: object

# %%
print(sample_data.columns)
# Out:
# Index(['Health_Status ', 'Starting_Weight', 'Extracted', 'Raw_ng_ul',
#        'Date_Enriched', 'Microbe_ng_ul', 'Microbe_Location',
#        'Microbe_clean_date/n', 'Host_ng_ul', 'Host_Location', 'Host_clean_y/n',
#        'Date_Libprep', 'Status ', 'Notes ', 'Seq_date', 'Host_Seq_date',
#        'Microbe_seq_file', 'Host_seq_file', 'Seq_Location (in Unity)',
#        'Sample_Code = datecollected_tagnumber_transect_samplenumber_species',
#        'Unnamed: 21', 'Year'],
#       dtype='object')

# %%
columns_to_drop = ["Unnamed: 21", "Sample_Code = datecollected_tagnumber_transect_samplenumber_species"]
sample_data = sample_data.drop(columns=columns_to_drop)

# %%
#remove unnecessary columns
#'Unnamed: 21'
#sample_data <- sample_data[, -c("Unnamed: 21", "Sample_Code = datecollected_tagnumber_transect_samplenumber_species")]
#'Sample_Code = datecollected_tagnumber_transect_samplenumber_species',
#sample_data["Sample_Code = datecollected_tagnumber_transect_samplenumber_species"] <- NULL
print(sample_data.columns)
# Out:
# Index(['Health_Status ', 'Starting_Weight', 'Extracted', 'Raw_ng_ul',
#        'Date_Enriched', 'Microbe_ng_ul', 'Microbe_Location',
#        'Microbe_clean_date/n', 'Host_ng_ul', 'Host_Location', 'Host_clean_y/n',
#        'Date_Libprep', 'Status ', 'Notes ', 'Seq_date', 'Host_Seq_date',
#        'Microbe_seq_file', 'Host_seq_file', 'Seq_Location (in Unity)', 'Year'],
#       dtype='object')

# %% [markdown]
# ## Healthy 2019

# %%
healthy=sample_data["Health_Status "]=="Healthy"

# %%
healthy_2019=sample_data[healthy & (sample_data["Year"]=="2019")]
healthy_2019
# Out:
#                           Health_Status  Starting_Weight  Extracted Raw_ng_ul  \
# 062019_BEL_CBC_T3_8_MCAV         Healthy               _  5_18_2022       7.8
# 062019_BEL_CBC_T2_16_MCAV        Healthy               _  5_18_2022       6.1
# 062019_BEL_CBC_T1_20_MCAV        Healthy               _  5_18_2022      20.8
# 102019_BEL_CBC_T1_25_PSTR        Healthy             151  5_25_2023      23.2
# 102019_BEL_CBC_T1_26_PSTR        Healthy             107  5_25_2023      23.1
# 102019_BEL_CBC_T1_27_PSTR        Healthy             198  5_30_2023      19.1
# 102019_BEL_CBC_T1_28_PSTR        Healthy             120  5_30_2023       7.2
# 102019_BEL_CBC_T1_29_PSTR        Healthy             106  5_30_2023       3.2
# 102019_BEL_CBC_T1_30_PSTR        Healthy             128   6_1_2023       8.6
# 102019_BEL_CBC_T1_31_PSTR        Healthy             128   6_1_2023      13.2
# 102019_BEL_CBC_T2_30_PSTR        Healthy             129   6_1_2023      32.6
# ...

# %%
# export list of samples that are healthy, sampled in 2019
healthy_2019_samples = healthy_2019.index.tolist()

# %% [markdown]
# ### healthy, 2019, mcav

# %%
# Filter for sample names including "MCAV"
healthy_2019_MCAV = [sample_name for sample_name in healthy_2019_samples if "MCAV" in sample_name]

# Print or use the filtered_samples list as needed
print(healthy_2019_MCAV)
# Out:
# ['062019_BEL_CBC_T3_8_MCAV', '062019_BEL_CBC_T2_16_MCAV', '062019_BEL_CBC_T1_20_MCAV', '062019_BEL_CBC_T1_24_MCAV', '062019_BEL_CBC_T3_9_MCAV', '062019_BEL_CBC_T3_14_MCAV', '062019_BEL_CBC_T3_1_MCAV', '062019_BEL_CBC_T3_15_MCAV', '062019_BEL_CBC_T1_16_MCAV', '062019_BEL_CBC_T3_16_MCAV', '062019_BEL_CBC_T1_3_MCAV', '062019_BEL_CBC_T2_5_MCAV', '062019_BEL_CBC_T3_6_MCAV']

# %%
len(healthy_2019_MCAV)
# Out:
# 13

# %%
# export list to txt file
file_name = 'healthy_2019_MCAV'

# Write the list to a text file
with open(file_name, 'w') as file:
    for sample_name in healthy_2019_MCAV:
        file.write(f"{sample_name}\n")

# %%
ls
# Out:
# CBC_ColonyData.csv              Metagenomics_Tracker_Belize.csv
# CBC_ColonyData_replacement.csv  disease_over_time.jpeg
# CBC_samples.csv                 healthy_2019_MCAV

# %%
### healthy, 2019 PAST

# %%
# Filter for sample names including "MCAV"
healthy_2019_MCAV = [sample_name for sample_name in healthy_2019_samples if "MCAV" in sample_name]

# Print or use the filtered_samples list as needed
print(healthy_2019_MCAV)
# Out:
# ['062019_BEL_CBC_T3_8_MCAV', '062019_BEL_CBC_T2_16_MCAV', '062019_BEL_CBC_T1_20_MCAV', '062019_BEL_CBC_T1_24_MCAV', '062019_BEL_CBC_T3_9_MCAV', '062019_BEL_CBC_T3_14_MCAV', '062019_BEL_CBC_T3_1_MCAV', '062019_BEL_CBC_T3_15_MCAV', '062019_BEL_CBC_T1_16_MCAV', '062019_BEL_CBC_T3_16_MCAV', '062019_BEL_CBC_T1_3_MCAV', '062019_BEL_CBC_T2_5_MCAV', '062019_BEL_CBC_T3_6_MCAV']

# %% [markdown]
# ## Diseased

# %%
sample_data.columns
# Out:
# Index(['Health_Status ', 'Starting_Weight', 'Extracted', 'Raw_ng_ul',
#        'Date_Enriched', 'Microbe_ng_ul', 'Microbe_Location',
#        'Microbe_clean_date/n', 'Host_ng_ul', 'Host_Location', 'Host_clean_y/n',
#        'Date_Libprep', 'Status ', 'Notes ', 'Seq_date', 'Host_Seq_date',
#        'Microbe_seq_file', 'Host_seq_file', 'Seq_Location (in Unity)', 'Year'],
#       dtype='object')

# %%
diseased_rows=sample_data['Health_Status '].str.contains('Disease') 
diseased=sample_data[diseased_rows]
diseased
# Out:
#                              Health_Status  Starting_Weight   Extracted  \
# 052022_BEL_CBC_T2_45_PSTR   Diseased_Margin             181  10_10_2023
# 052022_BEL_CBC_T2_46_PSTR   Diseased_Tissue             162  10_10_2023
# 052022_BEL_CBC_T1_70_MCAV          Diseased             117   6_14_2022
# 052022_BEL_CBC_T3_49_MCAV          Diseased             142   6_14_2022
# 052022_BEL_CBC_T3_51_MCAV          Diseased             104   6_14_2022
# 052022_BEL_CBC_T3_60_MCAV          Diseased             187   6_14_2022
# 052022_BEL_CBC_T1_13_MCAV          Diseased             133   6_14_2022
# 052022_BEL_CBC_T1_11_PSTR   Diseased_Tissue             133   6_15_2023
# 052022_BEL_CBC_T1_10_PSTR   Diseased_Margin             141   6_15_2023
# 062019_BEL_CBC_T1_52_PAST          Diseased               _   6_17_2022
# 122022_BEL_CBC_T1_120_OANN  Diseased_Margin              74   6_28_2023
# 122022_BEL_CBC_T1_136_OANN  Diseased_Tissue              76   6_28_2023
# ...

# %%
# export list of samples that are diseased
disease_samples = diseased.index.tolist()
disease_samples
# Out:
# ['052022_BEL_CBC_T2_45_PSTR',
#  '052022_BEL_CBC_T2_46_PSTR',
#  '052022_BEL_CBC_T1_70_MCAV',
#  '052022_BEL_CBC_T3_49_MCAV',
#  '052022_BEL_CBC_T3_51_MCAV',
#  '052022_BEL_CBC_T3_60_MCAV',
#  '052022_BEL_CBC_T1_13_MCAV',
#  '052022_BEL_CBC_T1_11_PSTR',
#  '052022_BEL_CBC_T1_10_PSTR',
#  '062019_BEL_CBC_T1_52_PAST',
#  '122022_BEL_CBC_T1_120_OANN',
#  '122022_BEL_CBC_T1_136_OANN',
#  '122022_BEL_CBC_T2_101_OFAV',
#  '122022_BEL_CBC_T2_102_OFAV',
#  '122022_BEL_CBC_T2_107_OANN',
#  '122022_BEL_CBC_T2_118_OANN',
#  '122022_BEL_CBC_T2_119_OANN',
#  '122022_BEL_CBC_T4_10_OFAV',
#  '122022_BEL_CBC_T4_9_OFAV']

# %% [markdown]
# ### Diseased MCAV

# %%
disease_MCAV = [sample_name for sample_name in disease_samples if "MCAV" in sample_name]

# Print or use the filtered_samples list as needed
print(disease_MCAV)
# Out:
# ['052022_BEL_CBC_T1_70_MCAV', '052022_BEL_CBC_T3_49_MCAV', '052022_BEL_CBC_T3_51_MCAV', '052022_BEL_CBC_T3_60_MCAV', '052022_BEL_CBC_T1_13_MCAV']

# %%
pwd()
# Out:
# '/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/metadata'

# %%
os.chdir('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/mcav/')

# %%
mkdir diseased_mcav
# Out:
# mkdir: cannot create directory ‘diseased_mcav’: File exists

# %%
os.chdir('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/mcav/diseased_mcav/')

# %%
# export list to txt file
#create filename 
file_name = 'diseased_MCAV'

# Write the list of diseased sample names to a text file
with open(file_name, 'w') as file:
    for sample_name in disease_MCAV:
        file.write(f"{sample_name}\n")

# %%
os.chdir('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/metadata/')

# %% [markdown]
# ### Diseased Margin MCAV

# %%
margin_rows=sample_data['Health_Status '].str.contains('Margin')
margin=sample_data[margin_rows]
margin
# Out:
#                              Health_Status  Starting_Weight   Extracted  \
# 052022_BEL_CBC_T2_45_PSTR   Diseased_Margin             181  10_10_2023
# 052022_BEL_CBC_T1_12_MCAV            Margin               _   6_10_2022
# 052022_BEL_CBC_T1_40_MCAV            Margin              70   6_14_2022
# 052022_BEL_CBC_T3_48_MCAV            Margin             155   6_14_2022
# 052022_BEL_CBC_T3_40_MCAV            Margin             139   6_14_2022
# 052022_BEL_CBC_T3_50_MCAV            Margin              56   6_14_2022
# 052022_BEL_CBC_T1_10_PSTR   Diseased_Margin             141   6_15_2023
# 122022_BEL_CBC_T1_120_OANN  Diseased_Margin              74   6_28_2023
# 122022_BEL_CBC_T2_101_OFAV  Diseased_Margin             119   6_28_2023
# 122022_BEL_CBC_T2_118_OANN  Diseased_Margin             126   6_28_2023
# 122022_BEL_CBC_T4_9_OFAV    Diseased_Margin              41   6_28_2023
#
#                            Raw_ng_ul Date_Enriched Microbe_ng_ul  \
# ...

# %%
# export list of samples that are margin
margin_samples = margin.index.tolist()
margin_samples
# Out:
# ['052022_BEL_CBC_T2_45_PSTR',
#  '052022_BEL_CBC_T1_12_MCAV',
#  '052022_BEL_CBC_T1_40_MCAV',
#  '052022_BEL_CBC_T3_48_MCAV',
#  '052022_BEL_CBC_T3_40_MCAV',
#  '052022_BEL_CBC_T3_50_MCAV',
#  '052022_BEL_CBC_T1_10_PSTR',
#  '122022_BEL_CBC_T1_120_OANN',
#  '122022_BEL_CBC_T2_101_OFAV',
#  '122022_BEL_CBC_T2_118_OANN',
#  '122022_BEL_CBC_T4_9_OFAV']

# %%
margin_MCAV = [sample_name for sample_name in margin_samples if "MCAV" in sample_name]

# Print or use the filtered_samples list as needed
print(margin_MCAV)
# t3-50 doesnt have seq - remove 
margin_MCAV.remove('052022_BEL_CBC_T3_50_MCAV')
print(margin_MCAV)
# Out:
# ['052022_BEL_CBC_T1_12_MCAV', '052022_BEL_CBC_T1_40_MCAV', '052022_BEL_CBC_T3_48_MCAV', '052022_BEL_CBC_T3_40_MCAV', '052022_BEL_CBC_T3_50_MCAV']
# ['052022_BEL_CBC_T1_12_MCAV', '052022_BEL_CBC_T1_40_MCAV', '052022_BEL_CBC_T3_48_MCAV', '052022_BEL_CBC_T3_40_MCAV']

# %%
sample_data.loc[margin_MCAV,:]
# Out:
#                           Health_Status  Starting_Weight  Extracted Raw_ng_ul  \
# 052022_BEL_CBC_T1_12_MCAV         Margin               _  6_10_2022       6.2
# 052022_BEL_CBC_T1_40_MCAV         Margin              70  6_14_2022      18.4
# 052022_BEL_CBC_T3_48_MCAV         Margin             155  6_14_2022      38.3
# 052022_BEL_CBC_T3_40_MCAV         Margin             139  6_14_2022      24.7
# 052022_BEL_CBC_T3_50_MCAV         Margin              56  6_14_2022         0
#
#                           Date_Enriched Microbe_ng_ul Microbe_Location  \
# 052022_BEL_CBC_T1_12_MCAV      7_6_2022           0.1              NaN
# 052022_BEL_CBC_T1_40_MCAV      7_6_2022           5.2              NaN
# 052022_BEL_CBC_T3_48_MCAV      7_6_2022           6.4              NaN
# 052022_BEL_CBC_T3_40_MCAV      7_6_2022           7.5              NaN
# 052022_BEL_CBC_T3_50_MCAV             _             _                _
#
# ...

# %%
# %mkdir /project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/mcav/margin_mcav

# %%
os.chdir('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/mcav/margin_mcav/')

# %%
# export list to txt file
#create filename 
file_name = 'margin_MCAV'

# Write the list of  sample names to a text file
with open(file_name, 'w') as file:
    for sample_name in margin_MCAV:
        file.write(f"{sample_name}\n")

# %%
len(margin_MCAV)+len(disease_MCAV)+len(healthy_2019_MCAV)
# Out:
# 22

# %%
print(len(sample_data.loc[(sample_data.index.str.contains('MCAV')),:]))
sample_data.loc[(sample_data.index.str.contains('MCAV')),:]
# Out:
# 28
#                           Health_Status  Starting_Weight  Extracted Raw_ng_ul  \
# 062019_BEL_CBC_T3_8_MCAV         Healthy               _  5_18_2022       7.8
# 062019_BEL_CBC_T2_16_MCAV        Healthy               _  5_18_2022       6.1
# 062019_BEL_CBC_T1_20_MCAV        Healthy               _  5_18_2022      20.8
# 052022_BEL_CBC_T1_12_MCAV         Margin               _  6_10_2022       6.2
# 062019_BEL_CBC_T1_24_MCAV        Healthy             177  6_13_2022       7.1
# 062019_BEL_CBC_T3_9_MCAV         Healthy             162  6_13_2022       0.8
# 062019_BEL_CBC_T3_14_MCAV        Healthy             162  6_13_2022       3.6
# 062019_BEL_CBC_T3_1_MCAV         Healthy             113  6_13_2022       3.9
# 062019_BEL_CBC_T3_15_MCAV        Healthy             199  6_13_2022       7.7
# 062019_BEL_CBC_T1_16_MCAV        Healthy             188  6_13_2022       8.6
# 052022_BEL_CBC_T1_40_MCAV         Margin              70  6_14_2022      18.4
# ...

# %% [markdown]
# ### Healthy 2022 MCAV

# %%
healthy_2022=sample_data[healthy & (sample_data["Year"]=="2022")]
healthy_2022
# Out:
#                            Health_Status  Starting_Weight  Extracted  \
# 052022_BEL_CBC_T2_59_OFAV         Healthy             174  10_3_2023
# 052022_BEL_CBC_T2_69_OANN         Healthy             134  10_3_2023
# 052022_BEL_CBC_T2_72_OFAV         Healthy              75  10_3_2023
# 052022_BEL_CBC_T2_71_OFAV         Healthy             168  10_3_2023
# 052022_BEL_CBC_T3_13_MCAV         Healthy               _  6_15_2022
# 052022_BEL_CBC_T3_1_MCAV          Healthy               _  6_15_2022
# 052022_BEL_CBC_T3_19_MCAV         Healthy               _  6_15_2022
# 052022_BEL_CBC_T2_10_MCAV         Healthy               _  6_15_2022
# 052022_BEL_CBC_T1_57_MCAV         Healthy               _  6_15_2022
# 052022_BEL_CBC_T3_8_PAST          Healthy               _  6_17_2022
# 052022_BEL_CBC_T1_35_OANN         Healthy            84.1  6_21_2023
# 052022_BEL_CBC_T1_41_OANN         Healthy             118  6_21_2023
# 052022_BEL_CBC_T3_65_OFAV         Healthy             167  6_21_2023
# ...

# %%
# export list of samples that are healthy, sampled in 2019
healthy_2022_samples = healthy_2022.index.tolist()

# %%
# Filter for sample names including "MCAV"
healthy_2022_MCAV = [sample_name for sample_name in healthy_2022_samples if "MCAV" in sample_name]

# Print or use the filtered_samples list as needed
print(healthy_2022_MCAV)
# Out:
# ['052022_BEL_CBC_T3_13_MCAV', '052022_BEL_CBC_T3_1_MCAV', '052022_BEL_CBC_T3_19_MCAV', '052022_BEL_CBC_T2_10_MCAV', '052022_BEL_CBC_T1_57_MCAV']

# %%
# total mcav samples should be 28
len(margin_MCAV)+len(disease_MCAV)+len(healthy_2019_MCAV)+len(healthy_2022_MCAV)
# Out:
# 28

# %%
# %mkdir /project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/mcav/healthy_2022_mcav

# %%
os.chdir('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/mcav/healthy_2022_mcav')

# %%
# export list to txt file
#create filename 
file_name = 'healthy_2022_MCAV'

# Write the list of  sample names to a text file
with open(file_name, 'w') as file:
    for sample_name in healthy_2022_MCAV:
        file.write(f"{sample_name}\n")

# %% [markdown]
# ### Search for colonies over time
# - trying to find diseased samples from the same healthy mcav colonies over time

# %%
cbc_samples=pd.read_csv('CBC_samples.csv', index_col=0)

# %%
cbc_samples.head()
# Out:
#            Country Location CollectionDate Transect  TransectNum OldTagNum  \
# Month_year
# 122022.0       BEL      CBC        12/5/22   CURLEW          4.0       NaN
# 92023.0        BEL      CBC        9/25/23   CBC30N          1.0       NaN
# 92023.0        BEL      CBC        9/25/23   CBC30N          1.0       NaN
# 92023.0        BEL      CBC        9/25/23   CBC30N          1.0       NaN
# 92023.0        BEL      CBC        9/25/23   CBC30N          1.0       NaN
#
#            NewTagNum Species Time_sampled Time_processed    Sample_type  \
# Month_year
# 122022.0          77    OFAV          NaN            NaN      Core_EtOH
# 92023.0            2    PAST          NaN            NaN  Core_RNAlater
# 92023.0           21    PAST          NaN            NaN  Core_RNAlater
# 92023.0            3    SSID          NaN            NaN  Core_RNAlater
# 92023.0           24    MCAV          NaN            NaN  Core_RNAlater
#
#            SampleNum Health_status   Sampling_notes  \
# ...

# %%
healthy_2019_MCAV
len(healthy_2019_MCAV)
# Out:
# 13

# %%
# Fill missing values in the 'Tubelabel_species' column with an empty string
cbc_samples['Tubelabel_species'] = cbc_samples['Tubelabel_species'].fillna('')

#search cbc_samples for samples in list
#empty dict
matching_rows = []
# iterate through samples
for sample in healthy_2019_MCAV:
    # find samples in cbc_samples
    matches = cbc_samples[(cbc_samples['Tubelabel_species'].str.contains(sample, case=False)) & (cbc_samples['Sample_type']=="Core_EtOH")]
    # and add to dict
    matching_rows.append(matches)
# convert to df and view
result_df = pd.concat(matching_rows)
result_df
# Out:
#            Country Location CollectionDate Transect  TransectNum OldTagNum  \
# Month_year
# 62019.0        BEL      CBC        6/23/19   Lagoon          3.0       369
# 62019.0        BEL      CBC        6/22/19    SR30N          2.0       305
# 62019.0        BEL      CBC        6/24/19   CBC30N          1.0       383
# 62019.0        BEL      CBC        6/26/19   CBC30N          1.0       359
# 62019.0        BEL      CBC        6/23/19   Lagoon          3.0       379
# 62019.0        BEL      CBC        6/23/19   Lagoon          3.0       301
# 62019.0        BEL      CBC        6/23/19   Lagoon          3.0       327
# 62019.0        BEL      CBC        6/23/19   Lagoon          3.0       363
# 62019.0        BEL      CBC        6/24/19   CBC30N          1.0       390
# 62019.0        BEL      CBC        6/23/19   Lagoon          3.0       374
# 62019.0        BEL      CBC        6/21/19   CBC30N          1.0       355
# ...

# %%
result_df.shape
#13 rows in result_df matches # of samples in healthy_2019_mcav sample list
# Out:
# (13, 19)

# %%
# if newtagnum is empty, fill with oldtagnum
result_df['NewTagNum'].fillna(result_df['OldTagNum'], inplace=True)

# %%
# search for associated tag nums in our samples
print(result_df.loc[:, ['NewTagNum', 'Tubelabel_species']])
#save tag numbers as a list
tag_values = result_df['NewTagNum']
print(tag_values)
# Out:
#            NewTagNum          Tubelabel_species
# Month_year
# 62019.0           14   062019_BEL_CBC_T3_8_MCAV
# 62019.0           60  062019_BEL_CBC_T2_16_MCAV
# 62019.0            7  062019_BEL_CBC_T1_20_MCAV
# 62019.0           15  062019_BEL_CBC_T1_24_MCAV
# 62019.0           15   062019_BEL_CBC_T3_9_MCAV
# 62019.0           17  062019_BEL_CBC_T3_14_MCAV
# 62019.0            2   062019_BEL_CBC_T3_1_MCAV
# 62019.0           22  062019_BEL_CBC_T3_15_MCAV
# 62019.0            8  062019_BEL_CBC_T1_16_MCAV
# 62019.0           21  062019_BEL_CBC_T3_16_MCAV
# 62019.0          355   062019_BEL_CBC_T1_3_MCAV
# 62019.0           59   062019_BEL_CBC_T2_5_MCAV
# 62019.0            9   062019_BEL_CBC_T3_6_MCAV
# Month_year
# 62019.0     14
# 62019.0     60
# 62019.0      7
# 62019.0     15
# 62019.0     15
# 62019.0     17
# 62019.0      2
# 62019.0     22
# 62019.0      8
# 62019.0     21
# 62019.0    355
# 62019.0     59
# 62019.0      9
# Name: NewTagNum, dtype: object

# %%
# search for tagnums in sample spreadsheet (to find all samples associated with those colonies)
# Convert tag_values to string
tag_values_str = tag_values.astype(str)
# Search for tag numbers in the 'NewTagNum' column of cbc_samples
matching_tags = cbc_samples[(cbc_samples['NewTagNum'].astype(str).isin(tag_values_str)) & (cbc_samples['Species']=="MCAV") & (cbc_samples['Sample_type']!="Immune")]
# Display the matching rows
matching_tags
# Out:
#            Country Location CollectionDate  Transect  TransectNum OldTagNum  \
# Month_year
# 92023.0        BEL      CBC        9/27/23    CBC30N          1.0       NaN
# 92023.0        BEL      CBC        9/27/23    CBC30N          1.0       NaN
# 92023.0        BEL      CBC        9/26/23     SR30N          2.0       NaN
# 92023.0        BEL      CBC        9/26/23     SR30N          2.0       NaN
# 92023.0        BEL      CBC        9/26/23     SR30N          2.0       NaN
# ...            ...      ...            ...       ...          ...       ...
# 42024.0     Belize      CBC        4/26/24     SR30N          2.0       NaN
# 42024.0     Belize      CBC        4/29/24  Hangman           6.0       NaN
# 42024.0     Belize      CBC        4/29/24  Hangman           6.0       NaN
# 42024.0     Belize      CBC        4/29/24  Hangman           6.0       NaN
# 42024.0     Belize      CBC        4/29/24  Hangman           6.0       NaN
#
# ...

# %%
# Fill missing values in the 'Health status' column with an empty string
matching_tags['Health_status'] = matching_tags['Health_status'].fillna('')

#search for diseased colonies within the matching tags
diseased_matching_tags=matching_tags['Health_status'].str.contains("Diseased", case=False)
diseased_matching_tags.sum()
diseased_mcav_tracking=matching_tags[diseased_matching_tags]
# Out:
# /tmp/ipykernel_376114/2954653354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_tags['Health_status'] = matching_tags['Health_status'].fillna('')

# %%
# get list of sample ids 
diseased_mcav_list=diseased_mcav_tracking['Tubelabel_species'].tolist()
diseased_mcav_list
# Out:
# ['122022_BEL_CBC_T3_106_MCAV',
#  '122022_BEL_CBC_T3_107_MCAV',
#  '122022_BEL_CBC_T3_132_MCAV',
#  '122022_BEL_CBC_T3_133_MCAV',
#  '122022_BEL_CBC_T1_144_MCAV',
#  '122022_BEL_CBC_T1_98_MCAV',
#  '052022_BEL_CBC_T1_12_MCAV',
#  '052022_BEL_CBC_T1_13_MCAV',
#  '052022_BEL_CBC_T1_26_MCAV',
#  '052022_BEL_CBC_T1_27_MCAV',
#  '052022_BEL_CBC_T1_37_MCAV',
#  '052022_BEL_CBC_T1_39_MCAV',
#  '052022_BEL_CBC_T1_40_MCAV',
#  '052022_BEL_CBC_T1_42_MCAV',
#  '052022_BEL_CBC_T1_43_MCAV',
#  '052022_BEL_CBC_T1_60_MCAV',
#  '052022_BEL_CBC_T1_70_MCAV',
#  '052022_BEL_CBC_T1_73_MCAV',
#  '052022_BEL_CBC_T3_21_MCAV',
#  '052022_BEL_CBC_T3_22_MCAV',
#  '052022_BEL_CBC_T3_4_MCAV',
#  '052022_BEL_CBC_T3_40_MCAV',
#  '052022_BEL_CBC_T3_48_MCAV',
#  '052022_BEL_CBC_T3_49_MCAV',
#  '052022_BEL_CBC_T3_5_MCAV',
#  '052022_BEL_CBC_T3_50_MCAV',
#  '052022_BEL_CBC_T3_51_MCAV',
#  '052022_BEL_CBC_T3_60_MCAV',
#  '052022_BEL_CBC_T3_7_MCAV',
#  '052022_BEL_CBC_T3_9_MCAV',
#  '',
#  '',
#  '',
#  '']

# %%
diseased.columns
# Out:
# Index(['Health_Status ', 'Starting_Weight', 'Extracted', 'Raw_ng_ul',
#        'Date_Enriched', 'Microbe_ng_ul', 'Microbe_Location',
#        'Microbe_clean_date/n', 'Host_ng_ul', 'Host_Location', 'Host_clean_y/n',
#        'Date_Libprep', 'Status ', 'Notes ', 'Seq_date', 'Host_Seq_date',
#        'Microbe_seq_file', 'Host_seq_file', 'Seq_Location (in Unity)', 'Year'],
#       dtype='object')

# %%
# search metagenomics tracker (diseased df is already filtered) for sample ids in diseased_mcav_list

#empty dict
matching_disease = []
# iterate through samples
for sample in diseased_mcav_list:
     # find samples in diseased df
    sample_match = diseased[diseased['Microbe_seq_file'].str.contains(sample, case=False)]
    # and add to dict
    matching_disease.append(sample_match)
# convert to df and view
matching_mcav_samples = pd.concat(matching_disease)
matching_mcav_samples
# Out:
#                              Health_Status  Starting_Weight  Extracted  \
# 052022_BEL_CBC_T1_13_MCAV          Diseased             133  6_14_2022
# 052022_BEL_CBC_T1_70_MCAV          Diseased             117  6_14_2022
# 052022_BEL_CBC_T3_49_MCAV          Diseased             142  6_14_2022
# 052022_BEL_CBC_T3_51_MCAV          Diseased             104  6_14_2022
# 052022_BEL_CBC_T3_60_MCAV          Diseased             187  6_14_2022
# ...                                     ...             ...        ...
# 122022_BEL_CBC_T2_107_OANN  Diseased_Tissue             104  6_28_2023
# 122022_BEL_CBC_T2_118_OANN  Diseased_Margin             126  6_28_2023
# 122022_BEL_CBC_T2_119_OANN  Diseased_Tissue             160  6_28_2023
# 122022_BEL_CBC_T4_10_OFAV   Diseased_Tissue             159  6_28_2023
# 122022_BEL_CBC_T4_9_OFAV    Diseased_Margin              41  6_28_2023
#
#                            Raw_ng_ul Date_Enriched Microbe_ng_ul  \
# ...

# %%
disease_MCAV
# Out:
# ['052022_BEL_CBC_T1_70_MCAV',
#  '052022_BEL_CBC_T3_49_MCAV',
#  '052022_BEL_CBC_T3_51_MCAV',
#  '052022_BEL_CBC_T3_60_MCAV',
#  '052022_BEL_CBC_T1_13_MCAV']

# %%
# samples match original list :)

# %% [markdown]
# # Functional Annotation
# - functional annotation of short reads using Humann
#     - https://github.com/biobakery/humann#configuration
# - help from Nikea https://github.com/nikeaulrich/COL_metagenomics/blob/main/COL_functional_analysis_012025_032024.ipynb
# -

# %% [markdown]
# ## Installation

# %%
# in home dir in terminal
pip install humann

# %%
Defaulting to user installation because normal site-packages is not writeable
Collecting humann
  Downloading humann-3.9.tar.gz (107.2 MB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 MB 7.5 MB/s eta 0:00:00
  Installing build dependencies ... done
  Getting requirements to build wheel ... done
  Preparing metadata (pyproject.toml) ... done
Building wheels for collected packages: humann
  Building wheel for humann (pyproject.toml) ... done
  Created wheel for humann: filename=humann-3.9-py3-none-any.whl size=105429153 sha256=76ea276508862dde55380efd5e3d0d73c966a324b7b740065adb6739bf73f59e
  Stored in directory: /home/brooke_sienkiewicz_student_uml_edu/.cache/pip/wheels/78/48/9b/a7994271a6b73526bf3108ceb0740362e4b0eb5f1c9462f474
Successfully built humann
Installing collected packages: humann
Successfully installed humann-3.9

# %%
Ran 186 tests in 55.649s

OK

# %%
# will be using shotgun seq files (fastq) or mapping files (bam)? 
# at the moment I do have bam files so i will go with that
# so do not need to download databases atm

# %% [markdown]
# ## Scripts

# %%
input_path = "/scratch4/workspace/brooke_sienkiewicz_student_uml_edu-bel_raw/${SPP}/mapping/${GROUP}"
input_file = "${sampleid}.bam"
humann --input $SAMPLE --output $OUTPUT_DIR

# %% [markdown]
# # Sample Organization and Summary Calculations

# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir('/project/pi_sarah_gignouxwolfsohn_uml_edu/brooke/metadata')

# %%
sample_data=pd.read_csv('CBC_samples.csv')

# %%
sample_data
# Out:
#       Month_year Country Location CollectionDate Transect   TransectNum  \
# 0       122022.0     BEL      CBC        12/5/22    CURLEW          4.0
# 1        92023.0     BEL      CBC        9/25/23    CBC30N          1.0
# 2        92023.0     BEL      CBC        9/25/23    CBC30N          1.0
# 3        92023.0     BEL      CBC        9/25/23    CBC30N          1.0
# 4        92023.0     BEL      CBC        9/25/23    CBC30N          1.0
# ...          ...     ...      ...            ...       ...          ...
# 1990     42024.0  Belize      CBC        4/29/24  Hangman           6.0
# 1991     42024.0  Belize      CBC        4/29/24  Hangman           6.0
# 1992     42024.0  Belize      CBC        4/29/24  Hangman           6.0
# 1993     42024.0  Belize      CBC        4/29/24  Hangman           6.0
# 1994     42024.0  Belize      CBC        4/29/24  Hangman           6.0
#
#      OldTagNum NewTagNum Species Time_sampled Time_processed    Sample_type  \
# 0          NaN        77    OFAV          NaN            NaN      Core_EtOH
# 1          NaN         2    PAST          NaN            NaN  Core_RNAlater
# 2          NaN        21    PAST          NaN            NaN  Core_RNAlater
# 3          NaN         3    SSID          NaN            NaN  Core_RNAlater
# 4          NaN        24    MCAV          NaN            NaN  Core_RNAlater
# ...        ...       ...     ...          ...            ...            ...
# 1990       NaN        34    OFAV        12:01          13:06  Core_RNAlater
# 1991       NaN        35    OFAV        12:06          13:07    Core_frozen
# 1992       NaN        35    OFAV        12:06          13:07  Core_RNAlater
# 1993       NaN        36    OANN        12:09          13:07    Core_frozen
# 1994       NaN        36    OANN        12:09          13:07  Core_RNAlater
#
#      SampleNum Health status   Sampling_notes           Tubelabel_species  \
# 0            2       Healthy              NaN    122022_BEL_CBC_T4_2_OFAV
# 1          171       Healthy          CLP 90%  092023_BEL_CBC_T1_171_PAST
# 2          172       Healthy            No CL  092023_BEL_CBC_T1_172_PAST
# 3          173       Healthy  CLP 80%; DC 20%  092023_BEL_CBC_T1_173_SSID
# 4          174       Healthy          CLP 10%  092023_BEL_CBC_T1_174_MCAV
# ...        ...           ...              ...                         ...
# 1990      1138       Healthy              NaN                         NaN
# 1991      1208       Healthy              NaN                         NaN
# 1992      1139       Healthy              NaN                         NaN
# 1993      1209       Healthy              NaN                         NaN
# 1994      1140       Healthy              NaN                         NaN
#
#      Sample_physical_location Extraction_physical_location Date_sequenced  \
# 0           UML_NARWHAL_R1_B5            UML_NARWHAL_R2_B3            NaN
# 1          UML_NARWHAL_R1_B10                          NaN            NaN
# 2          UML_NARWHAL_R1_B10                          NaN            NaN
# 3          UML_NARWHAL_R1_B10                          NaN            NaN
# 4          UML_NARWHAL_R1_B10                          NaN            NaN
# ...                       ...                          ...            ...
# 1990                      NaN                          NaN            NaN
# 1991                      NaN                          NaN            NaN
# 1992                      NaN                          NaN            NaN
# 1993                      NaN                          NaN            NaN
# 1994                      NaN                          NaN            NaN
#
#      Notes
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 1990   NaN
# 1991   NaN
# 1992   NaN
# 1993   NaN
# 1994   NaN
#
# [1995 rows x 20 columns]

# %% [markdown]
# ### Data Cleanup

# %%
# making df a little smaller
cols_drop=["Location","Sample_physical_location","Extraction_physical_location"]
sample_data.drop(columns=cols_drop,inplace=True)

# %%
# clean up column names
sample_data.columns
# Out:
# Index(['Month_year', 'Country', 'CollectionDate', 'Transect ', 'TransectNum',
#        'OldTagNum', 'NewTagNum', 'Species', 'Time_sampled', 'Time_processed',
#        'Sample_type', 'SampleNum', 'Health status', 'Sampling_notes',
#        'Tubelabel_species', 'Date_sequenced', 'Notes'],
#       dtype='object')

# %%
# remove space from 'Transect '
sample_data.rename(columns={'Transect ': 'Transect'}, inplace=True)
# replace space in 'Health status' with _
sample_data.rename(columns={'Health status': 'Health_status'}, inplace=True)
sample_data.columns
# Out:
# Index(['Month_year', 'Country', 'CollectionDate', 'Transect', 'TransectNum',
#        'OldTagNum', 'NewTagNum', 'Species', 'Time_sampled', 'Time_processed',
#        'Sample_type', 'SampleNum', 'Health_status', 'Sampling_notes',
#        'Tubelabel_species', 'Date_sequenced', 'Notes'],
#       dtype='object')

# %%
# convert dates to str
sample_data['Month_year'] = sample_data['Month_year'].astype(str)
# remove the decimal point
sample_data['Month_year'] = sample_data['Month_year'].str.replace('.0', '')

# add leading zeros where necessary
sample_data['Month_year'] = sample_data['Month_year'].str.pad(width=6, side='left', fillchar='0')
sample_data['Month_year']
# Out:
# 0       122022
# 1       092023
# 2       092023
# 3       092023
# 4       092023
#          ...
# 1990    042024
# 1991    042024
# 1992    042024
# 1993    042024
# 1994    042024
# Name: Month_year, Length: 1995, dtype: object

# %%
nan_values = sample_data[sample_data['Month_year'].str.contains("nan", na=False)]
print(nan_values.head(2))
nan_values.shape
# don't know how there's no more info on these samples...may need to go through commit history and figure out what these are
# Out:
#      Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 1152     000nan     NaN            NaN      NaN          NaN       NaN
# 1153     000nan     NaN            NaN      NaN          NaN       NaN
#
#      NewTagNum Species Time_sampled Time_processed Sample_type SampleNum  \
# 1152       NaN     NaN          NaN            NaN         NaN       NaN
# 1153       NaN     NaN          NaN            NaN         NaN       NaN
#
#      Health_status Sampling_notes Tubelabel_species Date_sequenced  \
# 1152           NaN            NaN            ___T__            NaN
# 1153           NaN            NaN            ___T__            NaN
#
#                               Notes
# 1152  At UML, don't know what it is
# 1153  At UML, don't know what it is
# (9, 17)

# %%
# delete na rows from only that col
sample_data = sample_data[~sample_data['Month_year'].str.contains("nan", na=False)]
# Reset index if needed
sample_data.reset_index(drop=True, inplace=True)
sample_data
# Out:
#      Month_year Country CollectionDate  Transect  TransectNum OldTagNum  \
# 0        122022     BEL        12/5/22    CURLEW          4.0       NaN
# 1        092023     BEL        9/25/23    CBC30N          1.0       NaN
# 2        092023     BEL        9/25/23    CBC30N          1.0       NaN
# 3        092023     BEL        9/25/23    CBC30N          1.0       NaN
# 4        092023     BEL        9/25/23    CBC30N          1.0       NaN
# ...         ...     ...            ...       ...          ...       ...
# 1981     042024  Belize        4/29/24  Hangman           6.0       NaN
# 1982     042024  Belize        4/29/24  Hangman           6.0       NaN
# 1983     042024  Belize        4/29/24  Hangman           6.0       NaN
# 1984     042024  Belize        4/29/24  Hangman           6.0       NaN
# 1985     042024  Belize        4/29/24  Hangman           6.0       NaN
#
#      NewTagNum Species Time_sampled Time_processed    Sample_type SampleNum  \
# 0           77    OFAV          NaN            NaN      Core_EtOH         2
# 1            2    PAST          NaN            NaN  Core_RNAlater       171
# 2           21    PAST          NaN            NaN  Core_RNAlater       172
# 3            3    SSID          NaN            NaN  Core_RNAlater       173
# 4           24    MCAV          NaN            NaN  Core_RNAlater       174
# ...        ...     ...          ...            ...            ...       ...
# 1981        34    OFAV        12:01          13:06  Core_RNAlater      1138
# 1982        35    OFAV        12:06          13:07    Core_frozen      1208
# 1983        35    OFAV        12:06          13:07  Core_RNAlater      1139
# 1984        36    OANN        12:09          13:07    Core_frozen      1209
# 1985        36    OANN        12:09          13:07  Core_RNAlater      1140
#
#      Health_status   Sampling_notes           Tubelabel_species  \
# 0          Healthy              NaN    122022_BEL_CBC_T4_2_OFAV
# 1          Healthy          CLP 90%  092023_BEL_CBC_T1_171_PAST
# 2          Healthy            No CL  092023_BEL_CBC_T1_172_PAST
# 3          Healthy  CLP 80%; DC 20%  092023_BEL_CBC_T1_173_SSID
# 4          Healthy          CLP 10%  092023_BEL_CBC_T1_174_MCAV
# ...            ...              ...                         ...
# 1981       Healthy              NaN                         NaN
# 1982       Healthy              NaN                         NaN
# 1983       Healthy              NaN                         NaN
# 1984       Healthy              NaN                         NaN
# 1985       Healthy              NaN                         NaN
#
#      Date_sequenced Notes
# 0               NaN   NaN
# 1               NaN   NaN
# 2               NaN   NaN
# 3               NaN   NaN
# 4               NaN   NaN
# ...             ...   ...
# 1981            NaN   NaN
# 1982            NaN   NaN
# 1983            NaN   NaN
# 1984            NaN   NaN
# 1985            NaN   NaN
#
# [1986 rows x 17 columns]

# %%
# confirming it dropped the right amount of rows to match nan_values
1995-9
# Out:
# 1986

# %%
# Extract month and year
sample_data.loc[:,'Month'] = sample_data.loc[:,'Month_year'].str[0:2]
sample_data.loc[:,'Year'] = sample_data.loc[:,'Month_year'].str[2:]
# Out:
# /tmp/ipykernel_3112/3282395172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data.loc[:,'Month'] = sample_data.loc[:,'Month_year'].str[0:2]
# /tmp/ipykernel_3112/3282395172.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data.loc[:,'Year'] = sample_data.loc[:,'Month_year'].str[2:]
#      Month_year Country CollectionDate  Transect  TransectNum OldTagNum  \
# 0        122022     BEL        12/5/22    CURLEW          4.0       NaN
# 1        092023     BEL        9/25/23    CBC30N          1.0       NaN
# 2        092023     BEL        9/25/23    CBC30N          1.0       NaN
# 3        092023     BEL        9/25/23    CBC30N          1.0       NaN
# 4        092023     BEL        9/25/23    CBC30N          1.0       NaN
# ...         ...     ...            ...       ...          ...       ...
# 1981     042024  Belize        4/29/24  Hangman           6.0       NaN
# 1982     042024  Belize        4/29/24  Hangman           6.0       NaN
# 1983     042024  Belize        4/29/24  Hangman           6.0       NaN
# 1984     042024  Belize        4/29/24  Hangman           6.0       NaN
# 1985     042024  Belize        4/29/24  Hangman           6.0       NaN
#
#      NewTagNum Species Time_sampled Time_processed    Sample_type SampleNum  \
# 0           77    OFAV          NaN            NaN      Core_EtOH         2
# 1            2    PAST          NaN            NaN  Core_RNAlater       171
# 2           21    PAST          NaN            NaN  Core_RNAlater       172
# 3            3    SSID          NaN            NaN  Core_RNAlater       173
# 4           24    MCAV          NaN            NaN  Core_RNAlater       174
# ...        ...     ...          ...            ...            ...       ...
# 1981        34    OFAV        12:01          13:06  Core_RNAlater      1138
# 1982        35    OFAV        12:06          13:07    Core_frozen      1208
# 1983        35    OFAV        12:06          13:07  Core_RNAlater      1139
# 1984        36    OANN        12:09          13:07    Core_frozen      1209
# 1985        36    OANN        12:09          13:07  Core_RNAlater      1140
#
#      Health_status   Sampling_notes           Tubelabel_species  \
# 0          Healthy              NaN    122022_BEL_CBC_T4_2_OFAV
# 1          Healthy          CLP 90%  092023_BEL_CBC_T1_171_PAST
# 2          Healthy            No CL  092023_BEL_CBC_T1_172_PAST
# 3          Healthy  CLP 80%; DC 20%  092023_BEL_CBC_T1_173_SSID
# 4          Healthy          CLP 10%  092023_BEL_CBC_T1_174_MCAV
# ...            ...              ...                         ...
# 1981       Healthy              NaN                         NaN
# 1982       Healthy              NaN                         NaN
# 1983       Healthy              NaN                         NaN
# 1984       Healthy              NaN                         NaN
# 1985       Healthy              NaN                         NaN
#
#      Date_sequenced Notes Month  Year
# 0               NaN   NaN    12  2022
# 1               NaN   NaN    09  2023
# 2               NaN   NaN    09  2023
# 3               NaN   NaN    09  2023
# 4               NaN   NaN    09  2023
# ...             ...   ...   ...   ...
# 1981            NaN   NaN    04  2024
# 1982            NaN   NaN    04  2024
# 1983            NaN   NaN    04  2024
# 1984            NaN   NaN    04  2024
# 1985            NaN   NaN    04  2024
#
# [1986 rows x 19 columns]

# %%
# convert columns to datetimes 
sample_data.loc[:,'Month_year']=pd.to_datetime(sample_data['Month_year'], format = '%m%Y').dt.date
# convert month numbers to month abbreviations 
sample_data.loc[:,'Month']=pd.to_datetime(sample_data['Month'], format = '%m').dt.month_name().str.slice(stop=3)

# %%
print(sample_data['Health_status'].unique())
# Out:
# ['Healthy' 'Diseased_Margin' 'Diseased_Tissue' nan 'CLP 100%'
#  'HealthyNot_Sampled' 'HealthyTissue' 'MISS_SAMPLE' 'MiSSING' 'MISSING'
#  'Diseased_tissue' 'Diseased_margin' 'Disease']

# %%
# first look at nan value 
nas=sample_data['Health_status'].isna()
na_health=sample_data[nas]
na_health.loc[:,("Month", "Year", "Health_status", "NewTagNum", "SampleNum", "Sample_type", "Sampling_notes")]
# don't know what to do with this...look at colonydata?
# why are there NAs in sampleNum??
# Out:
#      Month  Year Health_status NewTagNum SampleNum    Sample_type  \
# 85     Sep  2023           NaN        32       197  Core_RNAlater
# 566    May  2022           NaN       NaN       NaN            NaN
# 640    May  2022           NaN        15        11            TEM
# 1382   Jan  2024           NaN         3       558    Core_frozen
# 1383   Jan  2024           NaN         3       557  Core_RNAlater
# ...    ...   ...           ...       ...       ...            ...
# 1532   Jan  2024           NaN        55       603  Core_RNAlater
# 1533   Jan  2024           NaN        55       583         Immune
# 1534   Jan  2024           NaN        51       606    Core_frozen
# 1535   Jan  2024           NaN        51       605  Core_RNAlater
# 1536   Jan  2024           NaN        51       584         Immune
#
#      Sampling_notes
# 85         CLP 100%
# 566             NaN
# 640             NaN
# 1382            NaN
# 1383            NaN
# ...             ...
# 1532        Healthy
# 1533        Healthy
# 1534        CLB 30%
# 1535        CLB 30%
# 1536        CLB 30%
#
# [141 rows x 7 columns]

# %%
na_sample=sample_data['SampleNum'].isna()
nas_sample=sample_data[na_sample]
nas_sample
# Out:
#       Month_year Country CollectionDate Transect  TransectNum OldTagNum  \
# 475   2022-12-01     BEL        12/2/22   CBC30N          1.0       NaN
# 565   2022-05-01     BEL        5/22/22    SR30N          2.0       337
# 566   2022-05-01     BEL        5/22/22    SR30N          2.0       347
# 741   2022-05-01     BEL        5/20/22   Lagoon          3.0        21
# 742   2022-05-01     BEL        5/20/22   Lagoon          3.0       358
# 812   2019-10-01     BEL       10/15/19   CBC30N          1.0       407
# 813   2019-10-01     BEL       10/15/19   CBC30N          1.0       413
# 814   2019-10-01     BEL       10/15/19   CBC30N          1.0       418
# 815   2019-10-01     BEL       10/15/19   CBC30N          1.0       417
# 816   2019-10-01     BEL       10/15/19   CBC30N          1.0       404
# 817   2019-10-01     BEL       10/15/19   CBC30N          1.0       422
# 818   2019-10-01     BEL       10/15/19   CBC30N          1.0       419
# 839   2019-10-01     BEL       10/15/19   CBC30N          1.0       407
# 854   2019-10-01     BEL       10/13/19    SR30N          2.0       414
# 855   2019-10-01     BEL       10/13/19    SR30N          2.0       421
# 856   2019-10-01     BEL       10/13/19    SR30N          2.0       406
# 857   2019-10-01     BEL       10/13/19    SR30N          2.0       400
# 858   2019-10-01     BEL       10/13/19    SR30N          2.0       427
# 878   2019-06-01     BEL        6/26/19   CBC30N          1.0       359
# 881   2019-06-01     BEL        6/26/19   CBC30N          1.0       359
# 921   2019-06-01     BEL        6/24/19   CBC30N          1.0       395
# 922   2019-06-01     BEL        6/24/19   CBC30N          1.0       397
# 962   2019-06-01     BEL        6/23/19   Lagoon          3.0       367
# 963   2019-06-01     BEL        6/23/19   Lagoon          3.0       304
# 964   2019-06-01     BEL        6/23/19   Lagoon          3.0       369
# 965   2019-06-01     BEL        6/23/19   Lagoon          3.0       374
# 966   2019-06-01     BEL        6/23/19   Lagoon          3.0       378
# 967   2019-06-01     BEL        6/23/19   Lagoon          3.0        21
# 968   2019-06-01     BEL        6/23/19   Lagoon          3.0    12flag
# 969   2019-06-01     BEL        6/23/19   Lagoon          3.0       370
# 1066  2019-06-01     BEL        6/22/19    SR30N          2.0       305
# 1067  2019-06-01     BEL        6/22/19    SR30N          2.0       356
# 1068  2019-06-01     BEL        6/22/19    SR30N          2.0       328
# 1096  2019-06-01     BEL        6/21/19   CBC30N          1.0       355
# 1097  2019-06-01     BEL        6/21/19   CBC30N          1.0       333
# 1128  2019-06-01     BEL        6/21/19    SR30N          2.0       354
# 1129  2019-06-01     BEL        6/21/19    SR30N          2.0       339
#
#      NewTagNum Species Time_sampled Time_processed  Sample_type SampleNum  \
# 475          5    SSID          NaN            NaN  Core_frozen       NaN
# 565         53    MCAV          NaN            NaN          NaN       NaN
# 566        NaN    PAST          NaN            NaN          NaN       NaN
# 741          7    PAST          NaN            NaN          NaN       NaN
# 742         13    PAST          NaN            NaN          NaN       NaN
# 812          4    PSTR          NaN            NaN      Syringe       NaN
# 813          6    PSTR          NaN            NaN      Syringe       NaN
# 814         12    PSTR          NaN            NaN      Syringe       NaN
# 815        NaN    PSTR          NaN            NaN      Syringe       NaN
# 816        NaN    PSTR          NaN            NaN      Syringe       NaN
# 817        NaN    PSTR          NaN            NaN      Syringe       NaN
# 818        NaN    PSTR          NaN            NaN      Syringe       NaN
# 839          4    PSTR          NaN            NaN      Syringe       NaN
# 854         54    PSTR          NaN            NaN      Syringe       NaN
# 855         58    PSTR          NaN            NaN      Syringe       NaN
# 856         62    PSTR          NaN            NaN      Syringe       NaN
# 857         65    PSTR          NaN            NaN      Syringe       NaN
# 858        NaN    PSTR          NaN            NaN      Syringe       NaN
# 878         15    MCAV          NaN            NaN      Syringe       NaN
# 881         15    MCAV          NaN            NaN      Syringe       NaN
# 921         13    PAST          NaN            NaN      Syringe       NaN
# 922         21    PAST          NaN            NaN      Syringe       NaN
# 962          9    MCAV          NaN            NaN      Syringe       NaN
# 963         12    MCAV          NaN            NaN      Syringe       NaN
# 964         14    MCAV          NaN            NaN      Syringe       NaN
# 965         21    MCAV          NaN            NaN      Syringe       NaN
# 966        NaN    MMEA          NaN            NaN      Syringe       NaN
# 967          7    PAST          NaN            NaN      Syringe       NaN
# 968        NaN    PAST          NaN            NaN      Syringe       NaN
# 969         28    SSID          NaN            NaN      Syringe       NaN
# 1066        60    MCAV          NaN            NaN      Syringe       NaN
# 1067        61    MCAV          NaN            NaN      Syringe       NaN
# 1068       NaN    MMEA          NaN            NaN      Syringe       NaN
# 1096       NaN    MCAV          NaN            NaN      Syringe       NaN
# 1097       NaN    MCAV          NaN            NaN      Syringe       NaN
# 1128        64    CNAT          NaN            NaN      Syringe       NaN
# 1129        59    MCAV          NaN            NaN      Syringe       NaN
#
#            Health_status                                     Sampling_notes  \
# 475   HealthyNot_Sampled                                                NaN
# 565          MISS_SAMPLE                                                NaN
# 566                  NaN                                                NaN
# 741              MiSSING                                      Missed sample
# 742              MISSING                                                NaN
# 812              Healthy                                                NaN
# 813              Healthy               mucus sample taken adjacent to punch
# 814              Healthy               mucus sample taken adjacent to punch
# 815              Healthy               mucus sample taken adjacent to punch
# 816              Healthy               mucus sample taken adjacent to punch
# 817              Healthy               mucus sample taken adjacent to punch
# 818              Healthy               mucus sample taken adjacent to punch
# 839              Healthy                                                NaN
# 854              Healthy             took syringe samples adjacent to punch
# 855              Healthy             took syringe samples adjacent to punch
# 856              Healthy  took syringe samples adjacent to punch; 80 cm ...
# 857              Healthy             took syringe samples adjacent to punch
# 858              Healthy             took syringe samples adjacent to punch
# 878              Healthy                                                NaN
# 881              Healthy                                                NaN
# 921              Healthy                                                NaN
# 922              Healthy                                                NaN
# 962              Healthy                                                NaN
# 963              Healthy                                                NaN
# 964              Healthy                                                NaN
# 965              Healthy                                                NaN
# 966              Healthy                                                NaN
# 967              Healthy           orange tag; estimated size -- no picture
# 968              Healthy                                      temporary tag
# 969              Healthy                                                NaN
# 1066             Healthy  processing delayed because of power steering f...
# 1067             Healthy  processing delayed because of power steering f...
# 1068             Healthy  processing delayed because of power steering f...
# 1096             Healthy                                                NaN
# 1097             Healthy                                                NaN
# 1128             Healthy  processing delayed because of power steering f...
# 1129             Healthy  processing delayed because of power steering f...
#
#                Tubelabel_species Date_sequenced Notes Month  Year
# 475      122022_BEL_CBC_T1__SSID            NaN   NaN   Dec  2022
# 565      052022_BEL_CBC_T2__MCAV            NaN   NaN   May  2022
# 566      052022_BEL_CBC_T2__PAST            NaN   NaN   May  2022
# 741      052022_BEL_CBC_T3__PAST            NaN   NaN   May  2022
# 742      052022_BEL_CBC_T3__PAST            NaN   NaN   May  2022
# 812      102019_BEL_CBC_T1__PSTR            NaN   NaN   Oct  2019
# 813      102019_BEL_CBC_T1__PSTR            NaN   NaN   Oct  2019
# 814      102019_BEL_CBC_T1__PSTR            NaN   NaN   Oct  2019
# 815      102019_BEL_CBC_T1__PSTR            NaN   NaN   Oct  2019
# 816      102019_BEL_CBC_T1__PSTR            NaN   NaN   Oct  2019
# 817      102019_BEL_CBC_T1__PSTR            NaN   NaN   Oct  2019
# 818      102019_BEL_CBC_T1__PSTR            NaN   NaN   Oct  2019
# 839   102019_BEL_CBC_T1_N/A_PSTR            NaN   NaN   Oct  2019
# 854      102019_BEL_CBC_T2__PSTR            NaN   NaN   Oct  2019
# 855      102019_BEL_CBC_T2__PSTR            NaN   NaN   Oct  2019
# 856      102019_BEL_CBC_T2__PSTR            NaN   NaN   Oct  2019
# 857      102019_BEL_CBC_T2__PSTR            NaN   NaN   Oct  2019
# 858      102019_BEL_CBC_T2__PSTR            NaN   NaN   Oct  2019
# 878      062019_BEL_CBC_T1__MCAV            NaN   NaN   Jun  2019
# 881   062019_BEL_CBC_T1_N/A_MCAV            NaN   NaN   Jun  2019
# 921      062019_BEL_CBC_T1__PAST            NaN   NaN   Jun  2019
# 922      062019_BEL_CBC_T1__PAST            NaN   NaN   Jun  2019
# 962      062019_BEL_CBC_T3__MCAV            NaN   NaN   Jun  2019
# 963      062019_BEL_CBC_T3__MCAV            NaN   NaN   Jun  2019
# 964      062019_BEL_CBC_T3__MCAV            NaN   NaN   Jun  2019
# 965      062019_BEL_CBC_T3__MCAV            NaN   NaN   Jun  2019
# 966      062019_BEL_CBC_T3__MMEA            NaN   NaN   Jun  2019
# 967      062019_BEL_CBC_T3__PAST            NaN   NaN   Jun  2019
# 968      062019_BEL_CBC_T3__PAST            NaN   NaN   Jun  2019
# 969      062019_BEL_CBC_T3__SSID            NaN   NaN   Jun  2019
# 1066     062019_BEL_CBC_T2__MCAV            NaN   NaN   Jun  2019
# 1067     062019_BEL_CBC_T2__MCAV            NaN   NaN   Jun  2019
# 1068     062019_BEL_CBC_T2__MMEA            NaN   NaN   Jun  2019
# 1096     062019_BEL_CBC_T1__MCAV            NaN   NaN   Jun  2019
# 1097     062019_BEL_CBC_T1__MCAV            NaN   NaN   Jun  2019
# 1128     062019_BEL_CBC_T2__CNAT            NaN   NaN   Jun  2019
# 1129     062019_BEL_CBC_T2__MCAV            NaN   NaN   Jun  2019

# %%
# make all "disease tissue" entries uniform
#disease_status=sample_data['Health_status'].str.contains("disease",case=False)
#sample_data[disease_status]

# %%
# investigate weird ones
#entries_to_ignore= "

# %%
# load colony data to figure out health statuses of these samples 
colony_data=pd.read_csv('CBC_ColonyData.csv')
colony_data.drop(columns="Unnamed: 0",inplace=True)
colony_data.head()
# Out:
#   Date_InitialTag Transect  TransectNum OldTagNum NewTagNum Species  Meter  \
# 0         6/21/19   CBC30N            1       349         1    SSID    1.5
# 1         6/21/19   CBC30N            1       334         2    PAST    1.4
# 2         6/21/19   CBC30N            1       346         3    SSID    6.3
# 3        10/15/19   CBC30N            1       407         4    PSTR    6.5
# 4         6/24/19   CBC30N            1       394         5    SSID    4.3
#
#    Meters_90 Direction  Size_Class  ... 112023_Percentage  122023_Condition  \
# 0        0.5     right         5.0  ...               NaN          Diseased
# 1        0.1      left         4.0  ...              100%               CLB
# 2        0.8     right         5.0  ...            5%,95%               CLP
# 3        0.5     right         3.0  ...               NaN              Dead
# 4        1.2      left         5.0  ...               NaN          Diseased
#
#    122023_Percentage 012024_Condition 012024_Percentage 022024_Condition  \
# 0                NaN         Diseased               NaN         Diseased
# 1               100%             Dead               NaN               TL
# 2                80%              CLP               NaN              CLB
# 3                NaN             Dead               NaN             Dead
# 4                NaN         Diseased               NaN         Diseased
#
#   022024_Percentage 042024_Condition 042024_Percentage COLONIES_TO_LOOK_AT
# 0               NaN              NaN               NaN                 NaN
# 1               90%              NaN               NaN                 NaN
# 2               98%              NaN               NaN                 NaN
# 3               NaN              NaN               NaN                 NaN
# 4               NaN              NaN               NaN                 NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Summary Stats

# %%
# Goal: make summary df that shows how many samples were taken each year for each species - shows sum of sample types too

# %% [markdown]
# ### 2019

# %%
# filter for 2019 samples
s2019 = sample_data["Year"]=='2019'
samples_2019=sample_data[s2019]

# %%
print(sample_data['Health_status'].unique())
# Out:
# ['Healthy' 'Diseased_Margin' 'Diseased_Tissue' nan 'CLP 100%'
#  'HealthyNot_Sampled' 'HealthyTissue' 'MISS_SAMPLE' 'MiSSING' 'MISSING'
#  'Diseased_tissue' 'Diseased_margin' 'Disease']

# %%
healthy=samples_2019['Health_status']=="Healthy"
print("Total # of healthy samples in 2019:",healthy.sum())
# Out:
# Total # of healthy samples in 2019: 340

# %%
healthy_2019=samples_2019[healthy]
print(healthy_2019['OldTagNum'].unique())
healthy_2019['OldTagNum'].value_counts(ascending=True)
# Out:
# ['407' '413' '418' '417' '404' '422' '419' '408' '409' '412' '415' '411'
#  '423' '426' '414' '421' '406' '400' '427' '420' '403' '359' '389' '393'
#  '36' '34' '392' '41' '347' '387' '62' '56' '91' '47' '396' '395' '397'
#  '391' '388' '382' '384' '390' '381' '386' '385' '383' '380' '394' '367'
#  '304' '369' '374' '378' '21' '12flag' '370' '327' '358' '365' '300' '301'
#  '363' '307' '316' '364' '321' '345' '314' '22' '23' '24' '25' '373' '28'
#  '27' '29' '353' '350' '361' '379' '305' '356' '328' '343' '317' '325'
#  '320' '311' '337' '355' '333' '334' '329' '335' '357' '303' '349' '346'
#  '342' '354' '339' '341' '352' '348' '344' '330' '336']
# OldTagNum
# 341       1
# 409       2
# 415       2
# 412       2
# 423       2
#          ..
# 369       4
# 374       4
# 407       4
# 21        4
# 12flag    4
# Name: count, Length: 107, dtype: int64

# %%
print("Total # of healthy sampled COLONIES in 2019:",healthy_2019['OldTagNum'].value_counts().shape)
# Out:
# Total # of healthy sampled COLONIES in 2019: (107,)

# %%
# for each species in 2019, calculate total number of active tagged colonies and total num of samples taken

# %%
healthy_2019["Health_status"].unique()
# Out:
# array(['Healthy'], dtype=object)

# %%
# create dictionary with necessary columns 
d={"species":[], "tagged_colonies":[], "num_samples":[]}
# loop thru each species in healthy 2019 df
species_list=healthy_2019['Species'].unique()
for specie in species_list:
    # add specie name to 'species' col
    d["species"].append(specie)
    
    # determine num of tagged colonies
    sp=healthy_2019['Species']==specie
    sp_df=healthy_2019[sp]
    colonies=sp_df["OldTagNum"].nunique()
    
    #add num of tagged colonies to dict
    d["tagged_colonies"].append(colonies)
    
    #determine num of samples
    sp_df=healthy_2019[sp]
    samples=sp_df["SampleNum"].nunique()
    
    #add to dict
    d["num_samples"].append(samples)
#convert d to df
SampleCounts_healthy2019=pd.DataFrame.from_dict(d)
SampleCounts_healthy2019
# Out:
#   species  tagged_colonies  num_samples
# 0    PSTR               21           39
# 1    MCAV               24           56
# 2    PAST               20           52
# 3    SSID               28           60
# 4    MMEA               13           34
# 5    CNAT                1            3

# %%
# create dictionary with necessary columns 
d={"species":[],"Health_status":[], "tagged_colonies":[], "num_samples":[]}
# loop thru each species in healthy 2019 df
species_list=healthy_2019['Species'].unique()
statuses=healthy_2019["Health_status"].unique()

for specie in species_list:
    # add specie name to 'species' col
    d["species"].append(specie)
    
    # determine num of tagged colonies in each health status in each species
    # create species-specific df
    sp=healthy_2019['Species']==specie
    sp_df=healthy_2019[sp]
        
    for status in statuses:
        d["Health_status"].append(status)
        # create new df with each health status within each species 
        status_sp=sp_df["Health_status"]==status
        status_sp_df=sp_df[status_sp]
        
        colonies=status_sp_df["OldTagNum"].nunique()

        #add num of tagged colonies to dict
        d["tagged_colonies"].append(colonies)

        #determine num of samples in each health status in each species
        samples=status_sp_df["SampleNum"].nunique()

        #add to dict
        d["num_samples"].append(samples)
#convert d to df
d
SampleCounts_healthy2019=pd.DataFrame.from_dict(d)
SampleCounts_healthy2019
# Out:
#   species Health_status  tagged_colonies  num_samples
# 0    PSTR       Healthy               21           39
# 1    MCAV       Healthy               24           56
# 2    PAST       Healthy               20           52
# 3    SSID       Healthy               28           60
# 4    MMEA       Healthy               13           34
# 5    CNAT       Healthy                1            3

# %%
# matches Sarah's sheet: https://docs.google.com/spreadsheets/d/16jlkSd8hLOTxRQoi_4W6WPUSoKN-sNtz1ChALbn6HhU/edit#gid=0
# can we add in health status too? should we make one massive table for all years and such or split it up?

# %%
# there are still lots of issues with the data:
# - weird health statuses 
# - na values in important places like tagnum or date collected

# %%
sample_data.columns
# Out:
# Index(['Month_year', 'Country', 'CollectionDate', 'Transect', 'TransectNum',
#        'OldTagNum', 'NewTagNum', 'Species', 'Time_sampled', 'Time_processed',
#        'Sample_type', 'SampleNum', 'Health_status', 'Sampling_notes',
#        'Tubelabel_species', 'Date_sequenced', 'Notes', 'Month', 'Year'],
#       dtype='object')

# %%
sample_data["NewTagNum"].unique()
# Out:
# array(['77', '2', '21', '3', '24', '13', '20', '12', '25', '7', '19',
#        '27', '35', '1', '23', '5', '22', '9', '11', '16', '17', '79',
#        '76', '73', '72', '68', '69', '74', 'Not 51 but adjacent', '63',
#        '57', '55', '60', '54', '71', '75', '66', '67', '80', '30', '52',
#        '32', '56', '31', '59', '78', '94', '93', '100', '96', '95', '92',
#        '98', '97', '43', '28', '99', '53', '64', '29', '39', '38', '14',
#        '6', '8', '10', '33', '34', '4', '18', '36', '70', '65', 'NOTAG',
#        '15', '37', '26', '41', nan, '58', '62', '51', '61', 'Na',
#        '51/not 51', '50', '49', '48', '47', '46', '45', '44', '42', '40',
#        '66/41'], dtype=object)

# %%
# create dictionary with necessary columns 
d={"Year":[],"Species":[], "Health_status":[],"Tagged_colonies":[],"Num_samples":[]}
# create list of years and species
species_list=sample_data['Species'].unique()
years=sample_data['Year'].unique()
statuses=sample_data['Health_status'].unique()
# loop thru each species in healthy 2019 df
for year in years:
    for specie in species_list:
            d["Year"].append(year)

            #create df specific to the year
            df = sample_data["Year"]==year
            samples_year=sample_data[df]
            # add specie name to 'species' col
            d["Species"].append(specie)
            
            for status in statuses:
            # add health status to dict
                d["Health_status"].append(status)

                # loop thru statuses and determine num of samples
                each_status=sample_data["Health_status"]==status
                status_df=sample_data[each_status]
                sample_num=status_df["SampleNum"].nunique()

                #add num of samples to dict
                d["Num_samples"].append(sample_num)

                # determine num of tagged colonies
                sp=samples_year["Species"]==specie
                sp_df=samples_year[sp]
                colonies=sp_df["NewTagNum"].nunique()
                # there are still NAs so this isn't quite right yet 
                #add num of tagged colonies to dict
                d["Tagged_colonies"].append(colonies)

                #determine num of samples
                samples=sp_df["SampleNum"].nunique()

                #add to dict
                d["Num_samples"].append(samples)
#convert d to df

#SummaryTable=pd.DataFrame.from_dict(d)
#SummaryTable
print("year", len(d['Year']))
print("Species", len(d['Species']))
print("Tagged_colonies", len(d['Tagged_colonies']))
print("Health_status", len(d['Health_status']))
print("Num_samples", len(d['Num_samples']))
# Out:
# year 52
# Species 52
# Tagged_colonies 676
# Health_status 676
# Num_samples 1352

# %%
d
# Out:
# {'Year': ['2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2023',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2019',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024',
#   '2024'],
#  'Species': ['OFAV',
#   'PAST',
#   'SSID',
#   'MCAV',
#   'PSTR',
#   'OANN',
#   'DLAB',
#   'CNAT',
#   'DL',
#   'OANN/OFAV?',
#   'MMEA',
#   'OFAV/OANN',
#   'PAST ',
#   'OFAV',
#   'PAST',
#   'SSID',
#   'MCAV',
#   'PSTR',
#   'OANN',
#   'DLAB',
#   'CNAT',
#   'DL',
#   'OANN/OFAV?',
#   'MMEA',
#   'OFAV/OANN',
#   'PAST ',
#   'OFAV',
#   'PAST',
#   'SSID',
#   'MCAV',
#   'PSTR',
#   'OANN',
#   'DLAB',
#   'CNAT',
#   'DL',
#   'OANN/OFAV?',
#   'MMEA',
#   'OFAV/OANN',
#   'PAST ',
#   'OFAV',
#   'PAST',
#   'SSID',
#   'MCAV',
#   'PSTR',
#   'OANN',
#   'DLAB',
#   'CNAT',
#   'DL',
#   'OANN/OFAV?',
#   'MMEA',
#   'OFAV/OANN',
#   'PAST '],
#  'Tagged_colonies': [11,
#   16,
#   24,
#   23,
#   20,
#   8,
#   9,
#   1,
#   1,
#   1,
#   0,
#   0,
#   0,
#   11,
#   15,
#   23,
#   14,
#   9,
#   8,
#   8,
#   1,
#   0,
#   0,
#   0,
#   1,
#   2,
#   0,
#   16,
#   24,
#   17,
#   14,
#   0,
#   0,
#   1,
#   0,
#   0,
#   1,
#   0,
#   0,
#   22,
#   20,
#   27,
#   23,
#   21,
#   17,
#   8,
#   0,
#   0,
#   0,
#   0,
#   0,
#   1],
#  'Health_status': ['Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy',
#   'Healthy'],
#  'Num_samples': [897,
#   32,
#   897,
#   67,
#   897,
#   114,
#   897,
#   71,
#   897,
#   54,
#   897,
#   33,
#   897,
#   31,
#   897,
#   5,
#   897,
#   2,
#   897,
#   7,
#   897,
#   0,
#   897,
#   0,
#   897,
#   0,
#   897,
#   69,
#   897,
#   73,
#   897,
#   91,
#   897,
#   97,
#   897,
#   54,
#   897,
#   24,
#   897,
#   18,
#   897,
#   2,
#   897,
#   0,
#   897,
#   0,
#   897,
#   0,
#   897,
#   6,
#   897,
#   6,
#   897,
#   0,
#   897,
#   52,
#   897,
#   60,
#   897,
#   56,
#   897,
#   39,
#   897,
#   0,
#   897,
#   0,
#   897,
#   3,
#   897,
#   0,
#   897,
#   0,
#   897,
#   34,
#   897,
#   0,
#   897,
#   0,
#   897,
#   99,
#   897,
#   85,
#   897,
#   137,
#   897,
#   128,
#   897,
#   92,
#   897,
#   57,
#   897,
#   16,
#   897,
#   0,
#   897,
#   0,
#   897,
#   0,
#   897,
#   0,
#   897,
#   0,
#   897,
#   1]}

# %%
species_list=sample_data['Species'].unique()
species_list
# Out:
# array(['OFAV', 'PAST', 'SSID', 'MCAV', 'PSTR', 'OANN', 'DLAB', 'CNAT',
#        'DL', 'OANN/OFAV?', 'MMEA', 'OFAV/OANN', 'PAST '], dtype=object)

# %%
# Attempt 3: create diff dictionaries and for loops specific to each year then combine?

# create dictionary with necessary columns 
samples_2022={"Species":[], "Tagged_colonies":[], "Health_status":[],"Num_samples":[]}
# create list of species
species_list=sample_data['Species'].unique()

s2022 = sample_data["Year"]=='2022'
year_2022=sample_data[s2022]

# loop thru each species in 2022 df
for specie in species_list:
    # add specie name to 'species' col
    samples_2022["Species"].append(specie)
    
 # determine num of tagged colonies
    sp=year_2022["Species"]==specie
    sp_df=year_2022[sp]
    colonies=sp_df["NewTagNum"].nunique()
    # there are still NAs so this isn't quite right yet 
 # add num of tagged colonies to dict
    samples_2022["Tagged_colonies"].append(colonies)

 # make list of health status options
    statuses=sp_df['Health_status'].unique()
    
 # determine num of samples within each health status
    for status in statuses:
        # add health status to dict
        samples_2022["Health_status"].append(status)
        
        # loop thru statuses and determine num of samples
        status_2022=year_2022["Health_status"]==status
        status_df=year_2022[status_2022]
        sample_num=status_df["SampleNum"].nunique()

        #add to dict
        samples_2022["Num_samples"].append(sample_num)

#convert d to df
samples_2022
print(len(samples_2022["Species"]))
print(len(samples_2022["Tagged_colonies"]))
print(len(samples_2022["Health_status"]))
print(len(samples_2022["Num_samples"]))

#Summary2022=pd.DataFrame.from_dict(samples_2022)
#Summary2022
# Out:
# 13
# 13
# 31
# 31

# %%
samples_2022
# Out:
# {'Species': ['OFAV',
#   'PAST',
#   'SSID',
#   'MCAV',
#   'PSTR',
#   'OANN',
#   'DLAB',
#   'CNAT',
#   'DL',
#   'OANN/OFAV?',
#   'MMEA',
#   'OFAV/OANN',
#   'PAST '],
#  'Tagged_colonies': [11, 16, 24, 23, 20, 8, 9, 1, 1, 1, 0, 0, 0],
#  'Health_status': ['Healthy',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'Diseased_Margin',
#   'Healthy',
#   'Diseased_Tissue',
#   nan,
#   'MiSSING',
#   'MISSING',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'Healthy',
#   'HealthyNot_Sampled',
#   'Healthy',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'MISS_SAMPLE',
#   nan,
#   'Healthy',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'Diseased_Margin',
#   'Diseased_Tissue',
#   'Healthy',
#   'HealthyTissue',
#   'Healthy',
#   'Diseased_Tissue',
#   'Diseased_Margin',
#   'Healthy',
#   'Healthy',
#   'Healthy'],
#  'Num_samples': [145,
#   87,
#   92,
#   87,
#   145,
#   92,
#   0,
#   0,
#   0,
#   87,
#   92,
#   145,
#   0,
#   145,
#   87,
#   92,
#   0,
#   0,
#   145,
#   87,
#   92,
#   87,
#   92,
#   145,
#   1,
#   145,
#   92,
#   87,
#   145,
#   145,
#   145]}
